# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Real Madrid season-2425.csv')

# %%
df.head()
# Out:
#        Date    HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  Referee  \
# 0  15/08/24  Ath Bilbao   Getafe     1     1   D     1     0   H      NaN
# 1  15/08/24       Betis   Girona     1     1   D     1     0   H      NaN
# 2  16/08/24       Celta   Alaves     2     1   H     0     1   A      NaN
# 3  16/08/24  Las Palmas  Sevilla     2     2   D     1     1   D      NaN
# 4  17/08/24     Osasuna  Leganes     1     1   D     0     1   A      NaN
#
#    ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0  ...    4    2  15  12   5   6   4   1   0   0
# 1  ...    4    2  11   7   4   4   2   0   0   0
# 2  ...    4    2   8  23   3   3   3   2   0   0
# 3  ...    5    5  12  13   6   3   0   0   0   0
# 4  ...    5    4  14  12   6   4   3   2   0   0
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Date          0
# HomeTeam      0
# AwayTeam      0
# FTHG          0
# FTAG          0
# FTR           0
# HTHG          0
# HTAG          0
# HTR           0
# Referee     380
# HS            0
# AS            0
# HST           0
# AST           0
# HF            0
# AF            0
# HC            0
# AC            0
# HY            0
# AY            0
# HR            0
# AR            0
# dtype: int64

# %%
df.drop(columns=['Referee','Date'],inplace=True)

# %%
df['Points_Home'] = np.where(df['FTR'] == 'H', 3,
                 np.where(df['FTR'] == 'D', 1, 0))
df['Points_Away'] = np.where(df['FTR'] == 'A', 3,
                 np.where(df['FTR'] == 'D', 1, 0))

# %%
df.head(20)
# Out:
#        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  HF  \
# 0    Ath Bilbao       Getafe     1     1   D     1     0   H   7   9  ...  15
# 1         Betis       Girona     1     1   D     1     0   H  19  13  ...  11
# 2         Celta       Alaves     2     1   H     0     1   A   6  10  ...   8
# 3    Las Palmas      Sevilla     2     2   D     1     1   D  13  16  ...  12
# 4       Osasuna      Leganes     1     1   D     0     1   A  16  10  ...  14
# 5      Valencia    Barcelona     1     2   A     1     1   D   6  18  ...  11
# 6      Sociedad    Vallecano     1     2   A     0     0   D  11  12  ...  14
# 7      Mallorca  Real Madrid     1     1   D     0     1   A  12  13  ...  11
# 8    Valladolid      Espanol     1     0   H     1     0   H  12  10  ...  15
# 9    Villarreal   Ath Madrid     2     2   D     2     2   D   8  10  ...   6
# 10        Celta     Valencia     3     1   H     2     1   H   7  13  ...   9
# 11      Sevilla   Villarreal     1     2   A     1     1   D  15   6  ...  15
# 12      Osasuna     Mallorca     1     0   H     0     0   D  15  11  ...  10
# 13    Barcelona   Ath Bilbao     2     1   H     1     1   D  13   9  ...  11
# 14      Espanol     Sociedad     0     1   A     0     0   D  13   8  ...  14
# 15       Getafe    Vallecano     0     0   D     0     0   D  12   3  ...  16
# 16  Real Madrid   Valladolid     3     0   H     0     0   D  17   8  ...  10
# 17      Leganes   Las Palmas     2     1   H     0     0   D  10  10  ...  11
# 18       Alaves        Betis     0     0   D     0     0   D   3  13  ...  16
# 19   Ath Madrid       Girona     3     0   H     1     0   H  11  13  ...  11
#
#     AF  HC  AC  HY  AY  HR  AR  Points_Home  Points_Away
# 0   12   5   6   4   1   0   0            1            1
# 1    7   4   4   2   0   0   0            1            1
# 2   23   3   3   3   2   0   0            3            0
# 3   13   6   3   0   0   0   0            1            1
# 4   12   6   4   3   2   0   0            1            1
# 5   13   3   8   2   3   0   0            0            3
# 6   21  10   5   2   4   0   0            0            3
# 7    6   8   7   1   0   0   1            1            1
# 8    8   3   2   2   2   0   0            3            0
# 9   10   2   3   1   3   0   0            1            1
# 10  11   4   7   3   0   0   0            3            0
# 11   7   7   2   3   5   0   0            0            3
# 12   8   5   4   2   1   0   0            3            0
# 13  16   5   6   4   5   0   0            3            0
# 14  18   7   4   2   2   0   0            0            3
# 15  18   3   2   1   2   0   0            1            1
# 16  15   5   5   1   1   0   0            3            0
# 17  10   3   7   1   1   0   0            3            0
# 18  13   3   8   1   4   1   0            1            1
# 19  10   1   9   1   3   0   0            3            0
#
# [20 rows x 22 columns]

# %%
df.head()
# Out:
#      HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  HF  AF  \
# 0  Ath Bilbao   Getafe     1     1   D     1     0   H   7   9  ...  15  12
# 1       Betis   Girona     1     1   D     1     0   H  19  13  ...  11   7
# 2       Celta   Alaves     2     1   H     0     1   A   6  10  ...   8  23
# 3  Las Palmas  Sevilla     2     2   D     1     1   D  13  16  ...  12  13
# 4     Osasuna  Leganes     1     1   D     0     1   A  16  10  ...  14  12
#
#    HC  AC  HY  AY  HR  AR  Points_Home  Points_Away
# 0   5   6   4   1   0   0            1            1
# 1   4   4   2   0   0   0            1            1
# 2   3   3   3   2   0   0            3            0
# 3   6   3   0   0   0   0            1            1
# 4   6   4   3   2   0   0            1            1
#
# [5 rows x 22 columns]

# %%
print(df.columns)
# Out:
# Index(['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR',
#        'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR',
#        'AR', 'Points_Home', 'Points_Away'],
#       dtype='object')

# %%
df_home = df.groupby('HomeTeam')['Points_Home'].sum().reset_index()
df_away = df.groupby('AwayTeam')['Points_Away'].sum().reset_index()

# %%
df_home.rename(columns={'HomeTeam': 'Team'}, inplace=True)
df_away.rename(columns={'AwayTeam': 'Team'}, inplace=True)

# %%
df1=pd.merge(df_home,df_away,how='outer',on='Team')

# %%
df1['Points']=df1['Points_Home']+df1['Points_Away']

# %%
df1.sort_values(by='Points',ascending=False,inplace=True)

# %%
plt.figure(figsize=(20,10))
ax=sb.barplot(x='Team',y='Points',data=df1)
ax.set(xlabel='Teams',ylabel='Points')
plt.title('La_Liga Team Performances')
plt.show()

# %% [markdown]
# Inference: Barcelona is the winner of La-Liga 2024-25 season.
#            Las Palmas and Real Vallodid got relegated to La-Liga 2.

# %%
df['Points_Home'] = pd.to_numeric(df['Points_Home'], errors='coerce')

# %%
df['Points_Away'] = pd.to_numeric(df['Points_Away'], errors='coerce')

# %%
df.head()
# Out:
#      HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  HF  AF  \
# 0  Ath Bilbao   Getafe     1     1   D     1     0   H   7   9  ...  15  12
# 1       Betis   Girona     1     1   D     1     0   H  19  13  ...  11   7
# 2       Celta   Alaves     2     1   H     0     1   A   6  10  ...   8  23
# 3  Las Palmas  Sevilla     2     2   D     1     1   D  13  16  ...  12  13
# 4     Osasuna  Leganes     1     1   D     0     1   A  16  10  ...  14  12
#
#    HC  AC  HY  AY  HR  AR  Points_Home  Points_Away
# 0   5   6   4   1   0   0            1            1
# 1   4   4   2   0   0   0            1            1
# 2   3   3   3   2   0   0            3            0
# 3   6   3   0   0   0   0            1            1
# 4   6   4   3   2   0   0            1            1
#
# [5 rows x 22 columns]

# %%
df1.head()
# Out:
#            Team  Points_Home  Points_Away  Points
# 3     Barcelona           43           45      88
# 13  Real Madrid           49           35      84
# 2    Ath Madrid           46           30      76
# 19   Villarreal           34           36      70
# 1    Ath Bilbao           39           31      70

# %%
df2=df1.sort_values(by='Points_Home',ascending=False)
plt.figure(figsize=(20,10))
ax=sb.barplot(x='Team',y='Points_Home',data=df2)
ax.set(xlabel='Teams',ylabel='Points')
plt.title('La_Liga Team Performances at Home')
plt.show()

# %% [markdown]
# Inference: Real Madrid got the highest home wins in 2024-25 season

# %%
df3=df1.sort_values(by='Points_Away',ascending=False)
plt.figure(figsize=(20,10))
ax=sb.barplot(x='Team',y='Points_Away',data=df3)
ax.set(xlabel='Teams',ylabel='Points')
plt.title('La_Liga Team Performances at Away')
plt.show()

# %% [markdown]
# Inference: Barcelona got the highest away wins in 2024-25 LaLiga season

# %%
df1=df[(df['HomeTeam']=='Real Madrid')|(df['AwayTeam']=='Real Madrid')]

# %%
df1.head()
# Out:
#        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  HF  \
# 7      Mallorca  Real Madrid     1     1   D     0     1   A  12  13  ...  11
# 16  Real Madrid   Valladolid     3     0   H     0     0   D  17   8  ...  10
# 28   Las Palmas  Real Madrid     1     1   D     1     0   H   7  25  ...  16
# 38  Real Madrid        Betis     2     0   H     0     0   D  20  12  ...   8
# 43     Sociedad  Real Madrid     0     2   A     0     0   D  11  16  ...  12
#
#     AF  HC  AC  HY  AY  HR  AR  Points_Home  Points_Away
# 7    6   8   7   1   0   0   1            1            1
# 16  15   5   5   1   1   0   0            3            0
# 28  13   2   6   0   2   0   0            1            1
# 38  16   7   3   2   0   0   0            3            0
# 43   9   6   6   4   1   0   0            0            3
#
# [5 rows x 22 columns]

# %%
home = df1[(df1['HomeTeam'] == 'Real Madrid')]
away=df1[(df1['AwayTeam'] == 'Real Madrid')]

# %%
home.head()
# Out:
#        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  HF  \
# 16  Real Madrid  Valladolid     3     0   H     0     0   D  17   8  ...  10
# 38  Real Madrid       Betis     2     0   H     0     0   D  20  12  ...   8
# 56  Real Madrid     Espanol     4     1   H     0     0   D  31  10  ...   7
# 64  Real Madrid      Alaves     3     2   H     2     0   H  10  12  ...   7
# 85  Real Madrid  Villarreal     2     0   H     1     0   H  11  10  ...   7
#
#     AF  HC  AC  HY  AY  HR  AR  Points_Home  Points_Away
# 16  15   5   5   1   1   0   0            3            0
# 38  16   7   3   2   0   0   0            3            0
# 56   5   9   4   4   3   0   0            3            0
# 64  10   4   4   4   0   0   0            3            0
# 85  11   2   5   0   1   0   0            3            0
#
# [5 rows x 22 columns]

# %%
away.head(10)
# Out:
#        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  HF  \
# 7      Mallorca  Real Madrid     1     1   D     0     1   A  12  13  ...  11
# 28   Las Palmas  Real Madrid     1     1   D     1     0   H   7  25  ...  16
# 43     Sociedad  Real Madrid     0     2   A     0     0   D  11  16  ...  12
# 78   Ath Madrid  Real Madrid     1     1   D     0     0   D  12  12  ...  11
# 94        Celta  Real Madrid     1     2   A     0     1   A  13  10  ...  16
# 135     Leganes  Real Madrid     0     3   A     0     1   A   4  16  ...  17
# 148  Ath Bilbao  Real Madrid     2     1   H     0     0   D   9  10  ...  21
# 153      Girona  Real Madrid     0     3   A     0     1   A  10  10  ...   6
# 163   Vallecano  Real Madrid     3     3   D     2     2   D  14  13  ...  18
# 181    Valencia  Real Madrid     1     2   A     1     0   H   8  17  ...  16
#
#      AF  HC  AC  HY  AY  HR  AR  Points_Home  Points_Away
# 7     6   8   7   1   0   0   1            1            1
# 28   13   2   6   0   2   0   0            1            1
# 43    9   6   6   4   1   0   0            0            3
# 78   11   5   5   3   1   1   0            1            1
# 94   13   6   2   2   1   0   0            0            3
# 135  11   2   4   2   0   0   0            0            3
# 148   9   5   2   3   3   0   0            3            0
# 153   7   6   3   3   2   0   0            0            3
# 163   8   4   3   4   2   0   0            1            1
# 181   9   2   5   2   3   0   1            0            3
#
# [10 rows x 22 columns]

# %%
total_home_matches= home.shape[0]
total_away_matches= away.shape[0]

# %%
total_home_matches
# Out:
# 19

# %%
home_wins=home[home['FTR']=='H'].shape[0]
away_wins=away[away['FTR']=='A'].shape[0]

# %%
home_loss=home[home['FTR']=='A'].shape[0]
away_loss=away[away['FTR']=='H'].shape[0]

# %%
home_draws=home[home['FTR']=='D'].shape[0]
away_draws=away[away['FTR']=='D'].shape[0]

# %%
away_wins
# Out:
# 10

# %%
awaywinper = (away_wins/total_away_matches)*100
awaylossper = 100.00-awaywinper

# %%
awaywinper
# Out:
# 52.63157894736842

# %%
homewinper = (home_wins/total_home_matches)*100
homelossper = 100.00-homewinper

# %%
homelossper
# Out:
# 15.789473684210535

# %%
print(home.columns[4])
# Out:
# FTR

# %%
df1['FTR'] = df1[df1.columns[4]].replace({'H': 'Win', 'A': 'Loss', 'D': 'Draw'})
ftr_counts = df1['FTR'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(ftr_counts.values,           
        labels=ftr_counts.index)

plt.title('Distribution of Full Time Results (FTR) of Real Madrid')
plt.axis('equal')  
plt.show()
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\1951665852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['FTR'] = df1[df1.columns[4]].replace({'H': 'Win', 'A': 'Loss', 'D': 'Draw'})

# %%
home.head(20)
# Out:
#         HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  HF  \
# 16   Real Madrid  Valladolid     3     0   H     0     0   D  17   8  ...  10
# 38   Real Madrid       Betis     2     0   H     0     0   D  20  12  ...   8
# 56   Real Madrid     Espanol     4     1   H     0     0   D  31  10  ...   7
# 64   Real Madrid      Alaves     3     2   H     2     0   H  10  12  ...   7
# 85   Real Madrid  Villarreal     2     0   H     1     0   H  11  10  ...   7
# 104  Real Madrid   Barcelona     0     4   A     0     0   D   9  15  ...  15
# 119  Real Madrid     Osasuna     4     0   H     2     0   H  18   2  ...   9
# 143  Real Madrid      Getafe     2     0   H     2     0   H  13   8  ...   7
# 177  Real Madrid     Sevilla     4     2   H     3     1   H  16  10  ...   5
# 196  Real Madrid  Las Palmas     4     1   H     3     1   H  26   6  ...  11
# 224  Real Madrid  Ath Madrid     1     1   D     0     1   A  23  10  ...  14
# 246  Real Madrid      Girona     2     0   H     1     0   H  22   6  ...   1
# 263  Real Madrid   Vallecano     2     1   H     2     1   H  10  20  ...  12
# 282  Real Madrid     Leganes     3     2   H     1     2   A  24  10  ...   9
# 291  Real Madrid    Valencia     1     2   A     0     1   A  21  10  ...  10
# 317  Real Madrid  Ath Bilbao     1     0   H     0     0   D  22   3  ...   7
# 335  Real Madrid       Celta     3     2   H     2     0   H  17  14  ...   5
# 355  Real Madrid    Mallorca     2     1   H     0     1   A  39   4  ...   6
# 371  Real Madrid    Sociedad     2     0   H     1     0   H  16   9  ...   5
#
#      AF  HC  AC  HY  AY  HR  AR  Points_Home  Points_Away
# 16   15   5   5   1   1   0   0            3            0
# 38   16   7   3   2   0   0   0            3            0
# 56    5   9   4   4   3   0   0            3            0
# 64   10   4   4   4   0   0   0            3            0
# 85   11   2   5   0   1   0   0            3            0
# 104  17  10   3   2   5   0   0            0            3
# 119  16  11   3   0   2   0   0            3            0
# 143  26   5   3   2   6   0   0            3            0
# 177  14   6   6   1   2   0   0            3            0
# 196  13   8   2   0   1   0   1            3            0
# 224  13   6   1   1   3   0   0            1            1
# 246   7  11   5   0   2   0   0            3            0
# 263  17   4   6   3   1   0   0            3            0
# 282  13   8   3   1   4   0   0            3            0
# 291  13   9   4   0   4   0   0            0            3
# 317  15  14   1   1   2   0   0            3            0
# 335  11   4   6   2   1   0   0            3            0
# 355  15  26   0   0   3   0   0            3            0
# 371   7  11   4   0   0   0   0            3            0
#
# [19 rows x 22 columns]

# %%
away['FTR'] = away[away.columns[4]].replace({'A': 'Win', 'H': 'Loss', 'D': 'Draw'})
ftr_counts = home['FTR'].value_counts()  
plt.figure(figsize=(8, 8))
plt.pie(ftr_counts.values,           
        labels=ftr_counts.index)

plt.title('Distribution of Full Time Results (FTR) at home')
plt.axis('equal')  
plt.show()

# %%
away['FTR'] = away[away.columns[4]].replace({'A': 'Win', 'H': 'Loss', 'D': 'Draw'})
ftr_counts = away['FTR'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(ftr_counts.values,           
        labels=ftr_counts.index)

plt.title('Distribution of Full Time Results (FTR) at Away')
plt.axis('equal')  
plt.show()
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\3315454866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away['FTR'] = away[away.columns[4]].replace({'A': 'Win', 'H': 'Loss', 'D': 'Draw'})

# %%
home_wins = (home['FTR'] == 'Win').sum()
home_draws = (home['FTR'] == 'Draw').sum()
home_losses = (home['FTR'] == 'Loss').sum()

away_wins = (away['FTR'] == 'Win').sum()
away_draws = (away['FTR'] == 'Draw').sum()
away_losses = (away['FTR'] == 'Loss').sum()

# %%
performance = pd.DataFrame({
    'Win': [home_wins, away_wins],
    'Draw': [home_draws, away_draws],
    'Loss': [home_losses, away_losses]
}, index=['Home', 'Away'])

# %%
performance.head()
# Out:
#       Win  Draw  Loss
# Home    0     0     0
# Away   10     5     4

# %%
performance.plot(kind='bar', figsize=(8, 6))

plt.title("Real Madrid: Home vs Away Performance", fontsize=14, fontweight='bold')
plt.xlabel("Match Location")
plt.ylabel("Number of Matches")
plt.xticks(rotation=0)
plt.legend(title="Result")
plt.tight_layout()
plt.show()

# %% [markdown]
# Inference:Real Madrid Performed better at Home and suffered losses at away venue

# %%
df1['Goals Conceded'] = np.where(
    df1['HomeTeam'] == 'Real Madrid', df1['FTAG'],
    np.where(df1['AwayTeam'] == 'Real Madrid', df1['FTHG'], np.nan)
)
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\653830994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Goals Conceded'] = np.where(

# %%
df1.head()
# Out:
#        HomeTeam     AwayTeam  FTHG  FTAG   FTR  HTHG  HTAG HTR  HS  AS  ...  \
# 7      Mallorca  Real Madrid     1     1  Draw     0     1   A  12  13  ...
# 16  Real Madrid   Valladolid     3     0   Win     0     0   D  17   8  ...
# 28   Las Palmas  Real Madrid     1     1  Draw     1     0   H   7  25  ...
# 38  Real Madrid        Betis     2     0   Win     0     0   D  20  12  ...
# 43     Sociedad  Real Madrid     0     2  Loss     0     0   D  11  16  ...
#
#     AF  HC  AC  HY  AY  HR  AR  Points_Home  Points_Away  Goals Conceded
# 7    6   8   7   1   0   0   1            1            1             1.0
# 16  15   5   5   1   1   0   0            3            0             0.0
# 28  13   2   6   0   2   0   0            1            1             1.0
# 38  16   7   3   2   0   0   0            3            0             0.0
# 43   9   6   6   4   1   0   0            0            3             0.0
#
# [5 rows x 23 columns]

# %%
home_goals=df1[df1['HomeTeam']=='Real Madrid']
away_goals=df1[df1['AwayTeam']=='Real Madrid']

# %%
home_goals.head()
# Out:
#        HomeTeam    AwayTeam  FTHG  FTAG  FTR  HTHG  HTAG HTR  HS  AS  ...  AF  \
# 16  Real Madrid  Valladolid     3     0  Win     0     0   D  17   8  ...  15
# 38  Real Madrid       Betis     2     0  Win     0     0   D  20  12  ...  16
# 56  Real Madrid     Espanol     4     1  Win     0     0   D  31  10  ...   5
# 64  Real Madrid      Alaves     3     2  Win     2     0   H  10  12  ...  10
# 85  Real Madrid  Villarreal     2     0  Win     1     0   H  11  10  ...  11
#
#     HC  AC  HY  AY  HR  AR  Points_Home  Points_Away  Goals Conceded
# 16   5   5   1   1   0   0            3            0             0.0
# 38   7   3   2   0   0   0            3            0             0.0
# 56   9   4   4   3   0   0            3            0             1.0
# 64   4   4   4   0   0   0            3            0             2.0
# 85   2   5   0   1   0   0            3            0             0.0
#
# [5 rows x 23 columns]

# %%
away_goals.head()
# Out:
#       HomeTeam     AwayTeam  FTHG  FTAG   FTR  HTHG  HTAG HTR  HS  AS  ...  \
# 7     Mallorca  Real Madrid     1     1  Draw     0     1   A  12  13  ...
# 28  Las Palmas  Real Madrid     1     1  Draw     1     0   H   7  25  ...
# 43    Sociedad  Real Madrid     0     2  Loss     0     0   D  11  16  ...
# 78  Ath Madrid  Real Madrid     1     1  Draw     0     0   D  12  12  ...
# 94       Celta  Real Madrid     1     2  Loss     0     1   A  13  10  ...
#
#     AF  HC  AC  HY  AY  HR  AR  Points_Home  Points_Away  Goals Conceded
# 7    6   8   7   1   0   0   1            1            1             1.0
# 28  13   2   6   0   2   0   0            1            1             1.0
# 43   9   6   6   4   1   0   0            0            3             0.0
# 78  11   5   5   3   1   1   0            1            1             1.0
# 94  13   6   2   2   1   0   0            0            3             1.0
#
# [5 rows x 23 columns]

# %%
home_goals.rename(columns={'AwayTeam': 'Opponent'}, inplace=True)
away_goals.rename(columns={'HomeTeam': 'Opponent'}, inplace=True)
away_goals.drop('AwayTeam',axis=1, inplace=True)
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\2163490359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_goals.rename(columns={'AwayTeam': 'Opponent'}, inplace=True)
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\2163490359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away_goals.rename(columns={'HomeTeam': 'Opponent'}, inplace=True)
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\2163490359.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away_goals.drop('AwayTeam',axis=1, inplace=True)

# %%
away_goals.head()
# Out:
#       Opponent  FTHG  FTAG   FTR  HTHG  HTAG HTR  HS  AS  HST  ...  AF  HC  \
# 7     Mallorca     1     1  Draw     0     1   A  12  13    5  ...   6   8
# 28  Las Palmas     1     1  Draw     1     0   H   7  25    3  ...  13   2
# 43    Sociedad     0     2  Loss     0     0   D  11  16    2  ...   9   6
# 78  Ath Madrid     1     1  Draw     0     0   D  12  12    4  ...  11   5
# 94       Celta     1     2  Loss     0     1   A  13  10    5  ...  13   6
#
#     AC  HY  AY  HR  AR  Points_Home  Points_Away  Goals Conceded
# 7    7   1   0   0   1            1            1             1.0
# 28   6   0   2   0   0            1            1             1.0
# 43   6   4   1   0   0            0            3             0.0
# 78   5   3   1   1   0            1            1             1.0
# 94   2   2   1   0   0            0            3             1.0
#
# [5 rows x 22 columns]

# %%
Opponents = pd.concat([home_goals, away_goals], ignore_index=True)

# %%
Opponents=Opponents.groupby('Opponent').sum()

# %%
Opponents.sort_values(by='Goals Conceded',ascending=False).head(5)
# Out:
#               HomeTeam  FTHG  FTAG       FTR  HTHG  HTAG HTR  HS  AS  HST  \
# Opponent
# Barcelona  Real Madrid     4     7   LossWin     4     2  DH  32  24   13
# Vallecano  Real Madrid     5     4   WinDraw     4     3  HD  24  33   10
# Valencia   Real Madrid     2     4  LossLoss     1     1  AH  29  27   14
# Celta      Real Madrid     4     4   WinLoss     2     1  HA  30  24   11
# Alaves     Real Madrid     3     3   WinLoss     2     1  HA  23  23   10
#
#            ...  AF  HC  AC  HY  AY  HR  AR  Points_Home  Points_Away  \
# Opponent   ...
# Barcelona  ...  32  20   5   6   8   0   0            3            3
# Vallecano  ...  25   8   9   7   3   0   0            4            1
# Valencia   ...  22  11   9   2   7   0   1            0            6
# Celta      ...  24  10   8   4   2   0   0            3            3
# Alaves     ...  22   8   8   8   4   1   1            3            3
#
#            Goals Conceded
# Opponent
# Barcelona             8.0
# Vallecano             4.0
# Valencia              3.0
# Celta                 3.0
# Alaves                2.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Inference:Most Goals have been conceeded againt Barcelona

# %%
home_goals.drop('HF',axis=1,inplace=True)
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\2503149343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_goals.drop('HF',axis=1,inplace=True)

# %%
away_goals.drop('AF',axis=1,inplace=True)
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\3088464602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away_goals.drop('AF',axis=1,inplace=True)

# %%
home1=home_goals
away1=away_goals
df3=pd.merge(home1,away1,how='outer',on='Opponent')

# %%
df3['Total Fouls']=df3['HF']+df3['AF']

# %%
df3.sort_values(by='Total Fouls',ascending=False)
# Out:
#        HomeTeam    Opponent  FTHG_x  FTAG_x FTR_x  HTHG_x  HTAG_x HTR_x  HS_x  \
# 7   Real Madrid      Getafe       2       0   Win       2       0     H    13
# 1   Real Madrid  Ath Bilbao       1       0   Win       0       0     D    22
# 17  Real Madrid   Vallecano       2       1   Win       2       1     H    10
# 3   Real Madrid   Barcelona       0       4  Loss       0       0     D     9
# 4   Real Madrid       Betis       2       0   Win       0       0     D    20
# 12  Real Madrid     Osasuna       4       0   Win       2       0     H    18
# 0   Real Madrid      Alaves       3       2   Win       2       0     H    10
# 10  Real Madrid     Leganes       3       2   Win       1       2     A    24
# 15  Real Madrid    Valencia       1       2  Loss       0       1     A    21
# 9   Real Madrid  Las Palmas       4       1   Win       3       1     H    26
# 18  Real Madrid  Villarreal       2       0   Win       1       0     H    11
# 5   Real Madrid       Celta       3       2   Win       2       0     H    17
# 11  Real Madrid    Mallorca       2       1   Win       0       1     A    39
# 16  Real Madrid  Valladolid       3       0   Win       0       0     D    17
# 2   Real Madrid  Ath Madrid       1       1  Draw       0       1     A    23
# 13  Real Madrid     Sevilla       4       2   Win       3       1     H    16
# 6   Real Madrid     Espanol       4       1   Win       0       0     D    31
# 14  Real Madrid    Sociedad       2       0   Win       1       0     H    16
# 8   Real Madrid      Girona       2       0   Win       1       0     H    22
#
#     AS_x  ...  HC_y  AC_y  HY_y  AY_y  HR_y  AR_y  Points_Home_y  \
# 7      8  ...     4     4     3     1     0     0              0
# 1      3  ...     5     2     3     3     0     0              3
# 17    20  ...     4     3     4     2     0     0              1
# 3     15  ...    10     2     4     3     0     0              3
# 4     12  ...     9     2     3     4     0     0              3
# 12     2  ...     6     2     3     1     0     1              1
# 0     12  ...     4     4     4     4     1     1              0
# 10    10  ...     2     4     2     0     0     0              0
# 15    10  ...     2     5     2     3     0     1              0
# 9      6  ...     2     6     0     2     0     0              1
# 18    10  ...    11     4     2     1     0     0              0
# 5     14  ...     6     2     2     1     0     0              0
# 11     4  ...     8     7     1     0     0     1              1
# 16     8  ...     1     7     3     3     1     0              0
# 2     10  ...     5     5     3     1     1     0              1
# 13    10  ...     1     7     0     1     2     0              0
# 6     10  ...     1     8     2     0     0     0              3
# 14     9  ...     6     6     4     1     0     0              0
# 8      6  ...     6     3     3     2     0     0              0
#
#     Points_Away_y  Goals Conceded_y  Total Fouls
# 7               3               0.0           41
# 1               0               2.0           36
# 17              1               3.0           35
# 3               0               4.0           34
# 4               0               2.0           33
# 12              1               1.0           32
# 0               3               0.0           31
# 10              3               0.0           30
# 15              3               1.0           29
# 9               1               1.0           29
# 18              3               1.0           28
# 5               3               1.0           27
# 11              1               1.0           26
# 16              3               0.0           26
# 2               1               1.0           24
# 13              3               0.0           21
# 6               0               1.0           19
# 14              3               0.0           19
# 8               3               0.0           13
#
# [19 rows x 43 columns]

# %%
df3.head(1)
# Out:
#       HomeTeam Opponent  FTHG_x  FTAG_x FTR_x  HTHG_x  HTAG_x HTR_x  HS_x  \
# 0  Real Madrid   Alaves       3       2   Win       2       0     H    10
#
#    AS_x  ...  HC_y  AC_y  HY_y  AY_y  HR_y  AR_y  Points_Home_y  \
# 0    12  ...     4     4     4     4     1     1              0
#
#    Points_Away_y  Goals Conceded_y  Total Fouls
# 0              3               0.0           31
#
# [1 rows x 43 columns]

# %% [markdown]
# Alaves comitted the most fouls against Real Mdarid.

# %%
home_goals['Points Dropped']=np.where((home_goals['FTR']=='Win'),0,np.where((home_goals['FTR']=='Loss'),3,2))
home_goals.head(20)
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\68409303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_goals['Points Dropped']=np.where((home_goals['FTR']=='Win'),0,np.where((home_goals['FTR']=='Loss'),3,2))
#         HomeTeam    Opponent  FTHG  FTAG   FTR  HTHG  HTAG HTR  HS  AS  ...  \
# 16   Real Madrid  Valladolid     3     0   Win     0     0   D  17   8  ...
# 38   Real Madrid       Betis     2     0   Win     0     0   D  20  12  ...
# 56   Real Madrid     Espanol     4     1   Win     0     0   D  31  10  ...
# 64   Real Madrid      Alaves     3     2   Win     2     0   H  10  12  ...
# 85   Real Madrid  Villarreal     2     0   Win     1     0   H  11  10  ...
# 104  Real Madrid   Barcelona     0     4  Loss     0     0   D   9  15  ...
# 119  Real Madrid     Osasuna     4     0   Win     2     0   H  18   2  ...
# 143  Real Madrid      Getafe     2     0   Win     2     0   H  13   8  ...
# 177  Real Madrid     Sevilla     4     2   Win     3     1   H  16  10  ...
# 196  Real Madrid  Las Palmas     4     1   Win     3     1   H  26   6  ...
# 224  Real Madrid  Ath Madrid     1     1  Draw     0     1   A  23  10  ...
# 246  Real Madrid      Girona     2     0   Win     1     0   H  22   6  ...
# 263  Real Madrid   Vallecano     2     1   Win     2     1   H  10  20  ...
# 282  Real Madrid     Leganes     3     2   Win     1     2   A  24  10  ...
# 291  Real Madrid    Valencia     1     2  Loss     0     1   A  21  10  ...
# 317  Real Madrid  Ath Bilbao     1     0   Win     0     0   D  22   3  ...
# 335  Real Madrid       Celta     3     2   Win     2     0   H  17  14  ...
# 355  Real Madrid    Mallorca     2     1   Win     0     1   A  39   4  ...
# 371  Real Madrid    Sociedad     2     0   Win     1     0   H  16   9  ...
#
#      HC  AC  HY  AY  HR  AR  Points_Home  Points_Away  Goals Conceded  \
# 16    5   5   1   1   0   0            3            0             0.0
# 38    7   3   2   0   0   0            3            0             0.0
# 56    9   4   4   3   0   0            3            0             1.0
# 64    4   4   4   0   0   0            3            0             2.0
# 85    2   5   0   1   0   0            3            0             0.0
# 104  10   3   2   5   0   0            0            3             4.0
# 119  11   3   0   2   0   0            3            0             0.0
# 143   5   3   2   6   0   0            3            0             0.0
# 177   6   6   1   2   0   0            3            0             2.0
# 196   8   2   0   1   0   1            3            0             1.0
# 224   6   1   1   3   0   0            1            1             1.0
# 246  11   5   0   2   0   0            3            0             0.0
# 263   4   6   3   1   0   0            3            0             1.0
# 282   8   3   1   4   0   0            3            0             2.0
# 291   9   4   0   4   0   0            0            3             2.0
# 317  14   1   1   2   0   0            3            0             0.0
# 335   4   6   2   1   0   0            3            0             2.0
# 355  26   0   0   3   0   0            3            0             1.0
# 371  11   4   0   0   0   0            3            0             0.0
#
#      Points Dropped
# 16                0
# 38                0
# 56                0
# 64                0
# 85                0
# 104               3
# 119               0
# 143               0
# 177               0
# 196               0
# 224               2
# 246               0
# 263               0
# 282               0
# 291               3
# 317               0
# 335               0
# 355               0
# 371               0
#
# [19 rows x 23 columns]

# %%
away_goals['Points Dropped']=np.where((away_goals['FTR']=='Loss'),0,np.where((away_goals['FTR']=='Win'),3,2))
away_goals.head(20)
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\187543273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away_goals['Points Dropped']=np.where((away_goals['FTR']=='Loss'),0,np.where((away_goals['FTR']=='Win'),3,2))
#        Opponent  FTHG  FTAG   FTR  HTHG  HTAG HTR  HS  AS  HST  ...  HC  AC  \
# 7      Mallorca     1     1  Draw     0     1   A  12  13    5  ...   8   7
# 28   Las Palmas     1     1  Draw     1     0   H   7  25    3  ...   2   6
# 43     Sociedad     0     2  Loss     0     0   D  11  16    2  ...   6   6
# 78   Ath Madrid     1     1  Draw     0     0   D  12  12    4  ...   5   5
# 94        Celta     1     2  Loss     0     1   A  13  10    5  ...   6   2
# 135     Leganes     0     3  Loss     0     1   A   4  16    0  ...   2   4
# 148  Ath Bilbao     2     1   Win     0     0   D   9  10    3  ...   5   2
# 153      Girona     0     3  Loss     0     1   A  10  10    4  ...   6   3
# 163   Vallecano     3     3  Draw     2     2   D  14  13    5  ...   4   3
# 181    Valencia     1     2  Loss     1     0   H   8  17    5  ...   2   5
# 204  Valladolid     0     3  Loss     0     1   A   6  20    2  ...   1   7
# 214     Espanol     1     0   Win     0     0   D   5  21    2  ...   1   8
# 232     Osasuna     1     1  Draw     0     1   A  11  17    4  ...   6   2
# 253       Betis     2     1   Win     1     1   D  18   9    3  ...   9   2
# 271  Villarreal     1     2  Loss     1     2   A  23   9   10  ...  11   4
# 305      Alaves     0     1  Loss     0     1   A  13  11    6  ...   4   4
# 324      Getafe     0     1  Loss     0     1   A  20  14    6  ...   4   4
# 347   Barcelona     4     3   Win     4     2   H  23   9    9  ...  10   2
# 366     Sevilla     0     2  Loss     0     0   D   6  16    1  ...   1   7
#
#      HY  AY  HR  AR  Points_Home  Points_Away  Goals Conceded  Points Dropped
# 7     1   0   0   1            1            1             1.0               2
# 28    0   2   0   0            1            1             1.0               2
# 43    4   1   0   0            0            3             0.0               0
# 78    3   1   1   0            1            1             1.0               2
# 94    2   1   0   0            0            3             1.0               0
# 135   2   0   0   0            0            3             0.0               0
# 148   3   3   0   0            3            0             2.0               3
# 153   3   2   0   0            0            3             0.0               0
# 163   4   2   0   0            1            1             3.0               2
# 181   2   3   0   1            0            3             1.0               0
# 204   3   3   1   0            0            3             0.0               0
# 214   2   0   0   0            3            0             1.0               3
# 232   3   1   0   1            1            1             1.0               2
# 253   3   4   0   0            3            0             2.0               3
# 271   2   1   0   0            0            3             1.0               0
# 305   4   4   1   1            0            3             0.0               0
# 324   3   1   0   0            0            3             0.0               0
# 347   4   3   0   0            3            0             4.0               3
# 366   0   1   2   0            0            3             0.0               0
#
# [19 rows x 22 columns]

# %%
rm=pd.merge(home_goals,away_goals,how='outer',on='Opponent')

# %%
rm['Point Lost']=rm['Points Dropped_x']+rm['Points Dropped_y']
rm.sort_values(by='Point Lost',ascending=False)
# Out:
#        HomeTeam    Opponent  FTHG_x  FTAG_x FTR_x  HTHG_x  HTAG_x HTR_x  HS_x  \
# 3   Real Madrid   Barcelona       0       4  Loss       0       0     D     9
# 2   Real Madrid  Ath Madrid       1       1  Draw       0       1     A    23
# 4   Real Madrid       Betis       2       0   Win       0       0     D    20
# 6   Real Madrid     Espanol       4       1   Win       0       0     D    31
# 15  Real Madrid    Valencia       1       2  Loss       0       1     A    21
# 1   Real Madrid  Ath Bilbao       1       0   Win       0       0     D    22
# 9   Real Madrid  Las Palmas       4       1   Win       3       1     H    26
# 17  Real Madrid   Vallecano       2       1   Win       2       1     H    10
# 11  Real Madrid    Mallorca       2       1   Win       0       1     A    39
# 12  Real Madrid     Osasuna       4       0   Win       2       0     H    18
# 13  Real Madrid     Sevilla       4       2   Win       3       1     H    16
# 16  Real Madrid  Valladolid       3       0   Win       0       0     D    17
# 14  Real Madrid    Sociedad       2       0   Win       1       0     H    16
# 0   Real Madrid      Alaves       3       2   Win       2       0     H    10
# 10  Real Madrid     Leganes       3       2   Win       1       2     A    24
# 8   Real Madrid      Girona       2       0   Win       1       0     H    22
# 7   Real Madrid      Getafe       2       0   Win       2       0     H    13
# 5   Real Madrid       Celta       3       2   Win       2       0     H    17
# 18  Real Madrid  Villarreal       2       0   Win       1       0     H    11
#
#     AS_x  ...  AC_y  HY_y  AY_y  HR_y  AR_y  Points_Home_y  Points_Away_y  \
# 3     15  ...     2     4     3     0     0              3              0
# 2     10  ...     5     3     1     1     0              1              1
# 4     12  ...     2     3     4     0     0              3              0
# 6     10  ...     8     2     0     0     0              3              0
# 15    10  ...     5     2     3     0     1              0              3
# 1      3  ...     2     3     3     0     0              3              0
# 9      6  ...     6     0     2     0     0              1              1
# 17    20  ...     3     4     2     0     0              1              1
# 11     4  ...     7     1     0     0     1              1              1
# 12     2  ...     2     3     1     0     1              1              1
# 13    10  ...     7     0     1     2     0              0              3
# 16     8  ...     7     3     3     1     0              0              3
# 14     9  ...     6     4     1     0     0              0              3
# 0     12  ...     4     4     4     1     1              0              3
# 10    10  ...     4     2     0     0     0              0              3
# 8      6  ...     3     3     2     0     0              0              3
# 7      8  ...     4     3     1     0     0              0              3
# 5     14  ...     2     2     1     0     0              0              3
# 18    10  ...     4     2     1     0     0              0              3
#
#     Goals Conceded_y  Points Dropped_y  Point Lost
# 3                4.0                 3           6
# 2                1.0                 2           4
# 4                2.0                 3           3
# 6                1.0                 3           3
# 15               1.0                 0           3
# 1                2.0                 3           3
# 9                1.0                 2           2
# 17               3.0                 2           2
# 11               1.0                 2           2
# 12               1.0                 2           2
# 13               0.0                 0           0
# 16               0.0                 0           0
# 14               0.0                 0           0
# 0                0.0                 0           0
# 10               0.0                 0           0
# 8                0.0                 0           0
# 7                0.0                 0           0
# 5                1.0                 0           0
# 18               1.0                 0           0
#
# [19 rows x 45 columns]

# %% [markdown]
# Inference: Athletico Madrid and Barcelona were the toughest opponents this season

# %%
plt.figure(figsize=(20,5))
ax=sb.barplot(x='Opponent',y='Goals Conceded',data=Opponents.head(5))
plt.title("Most Goals Conceded")
plt.xlabel("Opponents")
plt.ylabel("Goals Conceded")
plt.show()

# %%
plt.figure(figsize=(20,5))
ax=sb.barplot(x='Opponent',y='Point Lost',data=rm.head(5))
plt.xlabel("Opponents")
plt.ylabel("Points Dropped")
plt.title("The Toughest Opponents")
plt.show()

# %% [markdown]
# Inference: Real Madrid Dropped the most points against Athletico Madrid and Barcelona

# %%
rm_matches = df[(df['HomeTeam'] == 'Real Madrid') | (df['AwayTeam'] == 'Real Madrid')]

# %%
df5=pd.merge(home_goals,away_goals,how='outer',on='Opponent')
df5.head()
# Out:
#       HomeTeam    Opponent  FTHG_x  FTAG_x FTR_x  HTHG_x  HTAG_x HTR_x  HS_x  \
# 0  Real Madrid      Alaves       3       2   Win       2       0     H    10
# 1  Real Madrid  Ath Bilbao       1       0   Win       0       0     D    22
# 2  Real Madrid  Ath Madrid       1       1  Draw       0       1     A    23
# 3  Real Madrid   Barcelona       0       4  Loss       0       0     D     9
# 4  Real Madrid       Betis       2       0   Win       0       0     D    20
#
#    AS_x  ...  HC_y  AC_y  HY_y  AY_y  HR_y  AR_y  Points_Home_y  \
# 0    12  ...     4     4     4     4     1     1              0
# 1     3  ...     5     2     3     3     0     0              3
# 2    10  ...     5     5     3     1     1     0              1
# 3    15  ...    10     2     4     3     0     0              3
# 4    12  ...     9     2     3     4     0     0              3
#
#    Points_Away_y  Goals Conceded_y  Points Dropped_y
# 0              3               0.0                 0
# 1              0               2.0                 3
# 2              1               1.0                 2
# 3              0               4.0                 3
# 4              0               2.0                 3
#
# [5 rows x 44 columns]

# %%
df5['Total Shots'] = df5['HS_x'] + df5['AS_y']
df5['Total Goals'] = df5['FTHG_x'] + df5['FTAG_y']
df5['Total SOT'] = df5['HST_x'] + df5['AST_y']
df5['Total Oppn Goals']=df5['FTHG_y'] + df5['FTAG_x']
df5['Total Oppn SOT'] = df5['HST_y'] + df5['AST_x']
df5['RM Efficiency']=df5['Total Goals']/df5['Total Shots']
df5['RM Save Efficiency']=df5['Total Oppn Goals']/df5['Total Oppn SOT']

# %%
correlation_shots_goals = df5[['Total Shots', 'Total Goals']].corr().iloc[0, 1]
correlation_sot_goals = df5[['Total SOT', 'Total Goals']].corr().iloc[0, 1]

# %%
avg_rm_eff = df5['RM Efficiency'].mean()
avg_opp_eff = 1-df5['Save Efficiency'].mean()

correlation_shots_goals, correlation_sot_goals, avg_rm_eff, avg_opp_eff
# Out:
# (0.09048485304332794,
#  0.22994336859934075,
#  0.13312067708073277,
#  0.714505961874383)

# %%
print("Real Madrid's Shot Efficiency is:",round(avg_rm_eff*100,2),"%")
# Out:
# Real Madrid's Shot Efficiency is: 13.31 %

# %%
print("Real Madrid's Save Efficiency is:",round(avg_opp_eff*100,2),"%")
# Out:
# Real Madrid's Save Efficiency is: 71.45 %

# %%
df = pd.read_csv("Real Madrid season-2425.csv")
rm = df[(df['HomeTeam'] == 'Real Madrid') | (df['AwayTeam'] == 'Real Madrid')].copy()
rm['Date'] = pd.to_datetime(rm['Date'], dayfirst=True)
rm.sort_values('Date', inplace=True)
# Out:
# C:\Users\Anu indrani Roy\AppData\Local\Temp\ipykernel_4004\2672242051.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   rm['Date'] = pd.to_datetime(rm['Date'], dayfirst=True)

# %%
rm['Points'] = np.where(
    rm['HomeTeam'] == 'Real Madrid',
    np.where(rm['FTR'] == 'H', 3, np.where(rm['FTR'] == 'A', 0, 1)),
    np.where(rm['FTR'] == 'A', 3, np.where(rm['FTR'] == 'H', 0, 1))
)

# %%
rm['Month'] = rm['Date'].dt.month
monthly_performance = rm.groupby('Month')['Points'].mean()

# %%
rm['Rolling_Points'] = rm['Points'].rolling(window=5, min_periods=1).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(rm['Date'], rm['Rolling_Points'], label='Rolling Avg (5 Matches)', color='royalblue')
plt.plot(rm['Date'], rm['Points'], label='Match Points', alpha=0.4, linestyle='--', marker='o', markersize=4)
plt.title('Real Madrid Performance Over Time (Rolling Avg of Points)')
plt.xlabel('Date')
plt.ylabel('Points')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Inference: The Performance dipped in the month of February and March.

# %%
rm.sort_values('Date', inplace=True)

# %%
rm.head()
# Out:
#          Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 7  2024-08-18     Mallorca  Real Madrid     1     1   D     0     1   A
# 16 2024-08-25  Real Madrid   Valladolid     3     0   H     0     0   D
# 28 2024-08-29   Las Palmas  Real Madrid     1     1   D     1     0   H
# 38 2024-09-01  Real Madrid        Betis     2     0   H     0     0   D
# 43 2024-09-14     Sociedad  Real Madrid     0     2   A     0     0   D
#
#     Referee  ...  AF  HC  AC  HY  AY  HR  AR  Points  Month  Rolling_Points
# 7       NaN  ...   6   8   7   1   0   0   1       1      8        1.000000
# 16      NaN  ...  15   5   5   1   1   0   0       3      8        2.000000
# 28      NaN  ...  13   2   6   0   2   0   0       1      8        1.666667
# 38      NaN  ...  16   7   3   2   0   0   0       3      9        2.000000
# 43      NaN  ...   9   6   6   4   1   0   0       3      9        2.200000
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(rm['Date'], rm['Points'], marker='o', linestyle='-')
plt.yticks([0, 1, 3], ['Loss', 'Draw', 'Win'])
plt.title('Real Madrid Match Results (W/D/L) Over the 2024-25 Season')
plt.xlabel('Date')
plt.ylabel('Match Result')
plt.grid(True)
plt.show()

# %%
rm.drop(columns={'Date','HomeTeam','AwayTeam','Points','Month','Rolling_Points','Referee','FTR'},inplace=True)

# %%
features = rm.columns.astype(str).tolist()
features
# Out:
# ['FTHG',
#  'FTAG',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR']

# %%
numeric_features = rm.select_dtypes(include='number').columns
corr_matrix = rm[numeric_features].corr()

# %%
plt.figure(figsize=(10, 8))
sb.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Match Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1.Home corners correlate well with home shots on target, suggesting having good set pieces on attack.
#
# 2.Home yellow cards rise with home fouls, showing disciplinary actions reflect aggressive play and lacking in good defense and backline
#   This trend is similarly seen in away fouls leading to cards being drawn'
#   Real Madrid must work on its defense line for providing better aggresive play and ball dominance.
#
# 3.If one team dominates shots on target, the other usually has fewer shots — typical in one-sided games.
#    Real Madrid lacked in having a proper balance in attack and defense leading to heavy dependance on Front Line.
#
#
# 4.Home red cards reduced home goals-Due to fewer men on field.
#   Real Madrid should work on its team formation to avoid rigid set piece and play.
